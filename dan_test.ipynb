# %%
import pandas as pd

import dlh_utils
from dlh_utils import utilities
from dlh_utils import sessions

from pyspark.sql import SparkSession, DataFrame

# %%
df = pd.read_csv(r"Z:\AIMS\AIMS_Confidence_Score_Clerical\All_Source_Files\Address_Cleaning_Input_Files\RETURN_FILES_Electoral_Register_55to64_6K_ADDRESS_CLEANING_INPUT.csv")

# %%
spark = sessions.getOrCreateSparkSession(appName = 'dlh_utils_demo', size = 'medium')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 spark = sessions.getOrCreateSparkSession(appName = 'dlh_utils_demo', size = 'medium')
#
# File d:\Address_Functions\.venv\lib\site-packages\dlh_utils\sessions.py:59, in getOrCreateSparkSession(appName, size, showConsoleProgress, shufflePartitions, defaultParallelism, memory, memoryOverhead, cores, maxExecutors)
#      22 """
#      23 Starts spark session dependent on size category specified
#      24 or starts custom session on specified parameters. Also generates
#    (...)
#      56   None at present.
#      57 """
#      58 # obtain spark UI url parameters
# ---> 59 url = 'spark-' + str(os.environ['CDSW_ENGINE_ID']) + \
#      60     '.' + str(os.environ['CDSW_DOMAIN'])
#      61 spark_ui = display(HTML(f'<a href=http://{url}s>Spark UI</a>'))
#      63 try:
#      64
# ...
